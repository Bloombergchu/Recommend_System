# %%
import pandas as pd
import scipy.sparse as sparse
import numpy as np
from scipy.sparse.linalg import spsolve
from pandas.api.types import CategoricalDtype
import random
import implicit
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import normalize

from implicit.als import AlternatingLeastSquares
from implicit.bpr import BayesianPersonalizedRanking
from implicit.datasets.movielens import get_movielens
from implicit.lmf import LogisticMatrixFactorization
from implicit.nearest_neighbours import (BM25Recommender, CosineRecommender,
                                         TFIDFRecommender, bm25_weight,tfidf_weight)
from tqdm import tqdm
import codecs
from tabulate import tabulate

# %%
retail_data = pd.read_json('data/cus_user_quality_date_0716.json') # This may take a couple minutes
# df2 = pd.read_csv('data/product_brand_type_color.csv') # This may take a couple minutes

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120442 entries, 0 to 120441
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CUSTOMER_DIM_KEY   120442 non-null  int64
#  1   PRODUCT_DIM_KEY    120442 non-null  int64
#  2   QUANTITY           120441 non-null  float64
#  3   PRODUCT_NAME       120435 non-null  object
#  4   COLOR              120442 non-null  object
#  5   PRODUCT_TYPE       120442 non-null  object
#  6   CATEGORY           120442 non-null  object
#  7   BRAND              120442 non-null  object
#  8   RESOLUTION_STATUS  120442 non-null  object
#  9   ORDER_DATE_KEY     120442 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 9.2+ MB

# %%
cleaned_retail = retail_data.loc[pd.isnull(retail_data.PRODUCT_NAME) == False]
cleaned_retail = cleaned_retail[cleaned_retail['PRODUCT_DIM_KEY'].isin(cleaned_retail[cleaned_retail['ORDER_DATE_KEY'] > 17533].PRODUCT_DIM_KEY)]
cleaned_retail['QUANTITY'] = cleaned_retail['QUANTITY'].fillna(0.0)
cleaned_retail = cleaned_retail[cleaned_retail.RESOLUTION_STATUS.isin(['COMPLETED', 'PENDING'])]
print('Duplicated rows: ' + str(cleaned_retail.duplicated().sum()))
cleaned_retail.drop_duplicates(inplace=True)
# Out:
# Duplicated rows: 280

# %%
cleaned_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51810 entries, 0 to 120440
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CUSTOMER_DIM_KEY   51810 non-null  int64
#  1   PRODUCT_DIM_KEY    51810 non-null  int64
#  2   QUANTITY           51810 non-null  float64
#  3   PRODUCT_NAME       51810 non-null  object
#  4   COLOR              51810 non-null  object
#  5   PRODUCT_TYPE       51810 non-null  object
#  6   CATEGORY           51810 non-null  object
#  7   BRAND              51810 non-null  object
#  8   RESOLUTION_STATUS  51810 non-null  object
#  9   ORDER_DATE_KEY     51810 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 4.3+ MB

# %%
grouped_cleaned = cleaned_retail.groupby(['CUSTOMER_DIM_KEY']).sum().reset_index() # Group together
grouped_cleaned.QUANTITY.loc[grouped_cleaned.QUANTITY == 0] = 1 # Replace a sum of zero purchases with a one to
# indicate purchased
grouped_customers = grouped_cleaned.query('QUANTITY > 0') # Only get customers where purchase totals were positive

customer_list = grouped_customers['CUSTOMER_DIM_KEY'].tolist()
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# group products by product_dim_key to sum the quantity
grouped_products = cleaned_retail.groupby(['PRODUCT_DIM_KEY','PRODUCT_NAME','PRODUCT_TYPE','BRAND'])['QUANTITY'].agg(sum)
grouped_products = grouped_products.reset_index().sort_values(['QUANTITY'],ascending=False)
grouped_products = grouped_products.query('QUANTITY > 0')
grouped_products
# Out:
#       PRODUCT_DIM_KEY                                       PRODUCT_NAME  \
# 8215           404102                                    Universal Glass
# 8214           404101                                     Bordeaux Glass
# 8213           404100                                     Burgundy Glass
# 8217           404104                                    Champagne Glass
# 4433           304248                         Milly Acrylic Tumbler Blue
# ...               ...                                                ...
# 9545           458004                           Baby Bunny Keepsake Bowl
# 9541           457966                          Bunny Luncheon Napkin Box
# 9605           458751                    Kitchen Timer by Michael Graves
# 9633           462256  Kaarl Mixed Black Large Cocktail Spoons, Set O...
# 3533           195913      Classico Twelve Guest Towels 14 X 20 In White
#
#                         PRODUCT_TYPE              BRAND  QUANTITY
# 8215                all purpose wine              Zalto    1783.0
# 8214                        red wine              Zalto    1109.0
# 8213                        red wine              Zalto     850.0
# 8217                       champagne              Zalto     742.0
# 4433  drinking glasses,bath tumblers  Mario Luca Giusti     721.0
# ...                              ...                ...       ...
# 9545                         Unknown       Arthur Court       1.0
# 9541      napkins,storage containers       Arthur Court       1.0
# 9605                         Unknown             Alessi       1.0
# 9633                 bar accessories      Blue Pheasant       1.0
# 3533                    guest towels             Sferra       0.5
#
# [16953 rows x 5 columns]

# %%
customer_id = 31773
customer_purchases = cleaned_retail[cleaned_retail['CUSTOMER_DIM_KEY']==customer_id].groupby(['PRODUCT_DIM_KEY','PRODUCT_NAME','PRODUCT_TYPE','BRAND'])['QUANTITY'].agg(sum)
customer_purchases = customer_purchases.reset_index().sort_values(['QUANTITY'],ascending=False)
customer_purchases
# Out:
#    PRODUCT_DIM_KEY                       PRODUCT_NAME PRODUCT_TYPE   BRAND  \
# 0           105507  Festival Napkins 20 X 20 in, Four      napkins  Sferra
#
#    QUANTITY
# 0       2.0

# %%
cus_top_list = pd.DataFrame(columns=['CUSTOMER_DIM_KEY', 'top_brand', 'top_type','brand_conf','type_conf']) 
for customer_id in tqdm(customer_list):
    customer_purchases = cleaned_retail[cleaned_retail['CUSTOMER_DIM_KEY']==customer_id].groupby(['PRODUCT_DIM_KEY','PRODUCT_NAME','PRODUCT_TYPE','BRAND'])['QUANTITY'].agg(sum)
    customer_purchases = customer_purchases.reset_index().sort_values(['QUANTITY'],ascending=False)
    customer_purchases

    # get brands of all items puchased by the customer
    customer_purchases_brand = cleaned_retail[cleaned_retail['CUSTOMER_DIM_KEY']==customer_id].groupby(['BRAND'])['QUANTITY'].agg(sum)
    customer_purchases_brand = customer_purchases_brand.reset_index().sort_values(['QUANTITY'],ascending=False)

    # The top buy item brand of the customer
    top_brand = customer_purchases_brand['BRAND'].iloc[0]
    brand_conf = customer_purchases_brand['QUANTITY'].iloc[0]/customer_purchases_brand['QUANTITY'].sum()

    # get types of all items puchased by the customer
    customer_purchases_type = cleaned_retail[cleaned_retail['CUSTOMER_DIM_KEY']==customer_id].groupby(['PRODUCT_TYPE'])['QUANTITY'].agg(sum)
    customer_purchases_type = customer_purchases_type.reset_index().sort_values(['QUANTITY'],ascending=False)

    # The top buy item type of the customer
    top_type = customer_purchases_type['PRODUCT_TYPE'].iloc[0]
    type_conf = customer_purchases_type['QUANTITY'].iloc[0]/customer_purchases_type['QUANTITY'].sum()

    cus = pd.DataFrame([[customer_id,top_brand, top_type, brand_conf, type_conf]]  , columns=['CUSTOMER_DIM_KEY', 'top_brand', 'top_type','brand_conf','type_conf']) 
    cus_top_list = pd.concat([cus_top_list,cus])
# Out:
#   0%|          | 132/27143 [00:01<05:10, 86.95it/s]G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   del sys.path[0]
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 27143/27143 [06:55<00:00, 65.37it/s]

# %%
cus_top_list.iloc[0]
# Out:
# CUSTOMER_DIM_KEY      31773
# top_brand            Sferra
# top_type            napkins
# brand_conf                1
# type_conf                 1
# Name: 0, dtype: object

# %%
# get type and brand of the item to find other items with the same type and brand
# type = grouped_products[grouped_products['PRODUCT_DIM_KEY']==item_id]['PRODUCT_TYPE'].iloc[0]
# brand = grouped_products[grouped_products['PRODUCT_DIM_KEY']==item_id]['BRAND'].iloc[0]


result = pd.DataFrame(columns=['CUSTOMER_DIM_KEY', 'PRODUCT_DIM_KEY','PRODUCT_NAME','top_brand', 'top_type','brand_conf','type_conf']) 

for i in tqdm(range(len(cus_top_list))):
    # customer
    item = cus_top_list.iloc[i]
    # purchase history
    customer_purchases = cleaned_retail[cleaned_retail['CUSTOMER_DIM_KEY']==item.CUSTOMER_DIM_KEY].groupby(['PRODUCT_DIM_KEY','PRODUCT_NAME','PRODUCT_TYPE','BRAND'])['QUANTITY'].agg(sum)
    customer_purchases = customer_purchases.reset_index().sort_values(['QUANTITY'],ascending=False)

    # get 3 dataframes, both type and brand matched items, type matched items and brand matched items

    matched = grouped_products[grouped_products['PRODUCT_TYPE']==item.top_type][grouped_products['BRAND']==item.top_brand]
    type_matched = grouped_products[grouped_products['PRODUCT_TYPE']==item.top_type]
    brand_matched = grouped_products[grouped_products['BRAND']==item.top_brand]

    matched['recom_class']='both'
    type_matched['recom_class']='type'
    brand_matched['recom_class']='brand'

    # concat type and brand matched and sort by quantity
    sort_matched = pd.concat([type_matched,brand_matched]).sort_values(['QUANTITY'],ascending=False)

    recom = pd.concat([matched,sort_matched]).drop_duplicates().head(20)
    recom['CUSTOMER_DIM_KEY'] = cus_top_list.iloc[i].CUSTOMER_DIM_KEY
    recom['top_brand'] = cus_top_list.iloc[i].top_brand
    recom['top_type'] = cus_top_list.iloc[i].top_type
    recom['brand_conf'] = cus_top_list.iloc[i].brand_conf
    recom['type_conf'] = cus_top_list.iloc[i].type_conf
    
    #result.append(recom.values.tolist())
    result = pd.concat([result,recom])
# Out:
#   0%|          | 0/27143 [00:00<?, ?it/s]G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 27143/27143 [1:04:59<00:00,  6.96it/s]

# %%
result
# Out:
#      CUSTOMER_DIM_KEY PRODUCT_DIM_KEY  \
# 3476            31773          194304
# 136             31773          105537
# 107             31773          104018
# 3477            31773          194308
# 133             31773          105511
# ...               ...             ...
# 1102            83510          135741
# 1682            83510          150412
# 1284            83510          142186
# 529             83510          125173
# 496             83510          124998
#
#                                            PRODUCT_NAME top_brand  \
# 3476                     Juliet Four Napkins 22 X 22 In    Sferra
# 136                   Festival Napkins 20 X 20 in, Four    Sferra
# 107                       Four Acanthus 22 X 22 Napkins    Sferra
# 3477                     Juliet Four Napkins 22 X 22 In    Sferra
# 133                   Festival Napkins 20 X 20 in, Four    Sferra
# ...                                                 ...       ...
# 1102                        Lastra White Condiment Bowl    Vietri
# 1682                      Campagna Uccello Dinner Plate    Vietri
# 1284                    Campagna Pesce Cereal/Soup Bowl    Vietri
# 529   Aladdin Clear Brilliant Three-Piece Child's Fl...    Vietri
# 496       Aladdin Blue Antique Five-Piece Place Setting    Vietri
#
#            top_type  brand_conf  type_conf         PRODUCT_TYPE   BRAND  \
# 3476        napkins         1.0        1.0              napkins  Sferra
# 136         napkins         1.0        1.0              napkins  Sferra
# 107         napkins         1.0        1.0              napkins  Sferra
# 3477        napkins         1.0        1.0              napkins  Sferra
# 133         napkins         1.0        1.0              napkins  Sferra
# ...             ...         ...        ...                  ...     ...
# 1102  waste baskets         1.0        1.0    condiment holders  Vietri
# 1682  waste baskets         1.0        1.0        dinner plates  Vietri
# 1284  waste baskets         1.0        1.0  cereal & soup bowls  Vietri
# 529   waste baskets         1.0        1.0             flatware  Vietri
# 496   waste baskets         1.0        1.0       place settings  Vietri
#
#       QUANTITY recom_class
# 3476     222.0        both
# 136      185.0        both
# 107      161.0        both
# 3477     157.0        both
# 133      100.0        both
# ...        ...         ...
# 1102      48.0       brand
# 1682      47.0       brand
# 1284      46.0       brand
# 529       46.0       brand
# 496       45.0       brand
#
# [542640 rows x 11 columns]

# %%
#for row in customer_purchases.itertuples():
    #if row.PRODUCT_DIM_KEY in recom.PRODUCT_DIM_KEY.head(20).tolist():
# Out:
#   File "<ipython-input-119-d8125b37014f>", line 2
#     if row.PRODUCT_DIM_KEY in recom.PRODUCT_DIM_KEY.head(20).tolist():
#                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
result[result['CUSTOMER_DIM_KEY']==55974]
# Out:
#      CUSTOMER_DIM_KEY PRODUCT_DIM_KEY  \
# 1457            55974          146802
# 641             55974          126746
# 1464            55974          147004
# 7471            55974          392614
# 1454            55974          146790
# 1262            55974          142067
# 605             55974          126625
# 562             55974          126130
# 197             55974          108370
# 1266            55974          142073
# 2590            55974          179847
# 773             55974          130491
# 1457            55974          146802
# 1457            55974          146802
# 257             55974          110052
# 2558            55974          179241
# 1269            55974          142078
# 1456            55974          146800
# 603             55974          126622
# 604             55974          126623
#
#                                            PRODUCT_NAME        top_brand  \
# 1457  Simply Anna Gold Bread & Butter Plate 6.25 in ...  Anna Weatherley
# 641   Bouquet of Flowers Bread & Butter Plate 6.25 i...  Anna Weatherley
# 1464  Simply Anna Polka Gold Bread & Butter Plate 6....  Anna Weatherley
# 7471  Vario White Bread & Butter Plate 7 1/2 In Tria...  Anna Weatherley
# 1454        Simply Anna Gold Dinner Plate 10.5 in Round  Anna Weatherley
# 1262             Powder Blue Dinner Plate 10.5 in Round  Anna Weatherley
# 605   Anna's Palette Aqua Green Dinner Plate 10.5 in...  Anna Weatherley
# 562           Blanc De Blanc Bread & Butter Plate 6.25"  Anna Weatherley
# 197   Hemisphere White Bread & Butter Plate 6.25 in ...  Anna Weatherley
# 1266        Powder Blue Salad/ Dessert Plate 9 in Round  Anna Weatherley
# 2590       TAC 02 White Bread & Butter Plate 6 1/4 inch  Anna Weatherley
# 773           Chargers Mint Green Charger 12.5 in Round  Anna Weatherley
# 1457  Simply Anna Gold Bread & Butter Plate 6.25 in ...  Anna Weatherley
# 1457  Simply Anna Gold Bread & Butter Plate 6.25 in ...  Anna Weatherley
# 257               Wing Song Bread & Butter Plate 6.5 in  Anna Weatherley
# 2558  Arcades Grey & Matte Gold Bread & Butter Plate...  Anna Weatherley
# 1269  Powder Blue Soup Bowl 1.75 in High 24 oz 9 in ...  Anna Weatherley
# 1456                       Simply Anna Gold Salad Plate  Anna Weatherley
# 603        Antique White with Gold Tea Cup 2.25 in High  Anna Weatherley
# 604       Antique White with Gold Tea Saucer 6 in Round  Anna Weatherley
#
#                    top_type  brand_conf  type_conf  \
# 1457  bread & butter plates         1.0   0.545455
# 641   bread & butter plates         1.0   0.545455
# 1464  bread & butter plates         1.0   0.545455
# 7471  bread & butter plates         1.0   0.545455
# 1454  bread & butter plates         1.0   0.545455
# 1262  bread & butter plates         1.0   0.545455
# 605   bread & butter plates         1.0   0.545455
# 562   bread & butter plates         1.0   0.545455
# 197   bread & butter plates         1.0   0.545455
# 1266  bread & butter plates         1.0   0.545455
# 2590  bread & butter plates         1.0   0.545455
# 773   bread & butter plates         1.0   0.545455
# 1457  bread & butter plates         1.0   0.545455
# 1457  bread & butter plates         1.0   0.545455
# 257   bread & butter plates         1.0   0.545455
# 2558  bread & butter plates         1.0   0.545455
# 1269  bread & butter plates         1.0   0.545455
# 1456  bread & butter plates         1.0   0.545455
# 603   bread & butter plates         1.0   0.545455
# 604   bread & butter plates         1.0   0.545455
#
#                                PRODUCT_TYPE                  BRAND  QUANTITY  \
# 1457                  bread & butter plates        Anna Weatherley      43.0
# 641                   bread & butter plates        Anna Weatherley       7.0
# 1464                  bread & butter plates        Anna Weatherley       3.0
# 7471                  bread & butter plates              Rosenthal      72.0
# 1454                          dinner plates        Anna Weatherley      72.0
# 1262                          dinner plates        Anna Weatherley      60.0
# 605                           dinner plates        Anna Weatherley      57.0
# 562                   bread & butter plates  Philippe Deshoulieres      49.0
# 197                   bread & butter plates            J.L. Coquet      48.0
# 1266  dessert plates,salad & dessert plates        Anna Weatherley      47.0
# 2590                  bread & butter plates              Rosenthal      45.0
# 773     buffet & chargers,buffet & chargers        Anna Weatherley      45.0
# 1457                  bread & butter plates        Anna Weatherley      43.0
# 1457                  bread & butter plates        Anna Weatherley      43.0
# 257                   bread & butter plates                Raynaud      40.0
# 2558                  bread & butter plates  Philippe Deshoulieres      39.0
# 1269                    cereal & soup bowls        Anna Weatherley      36.0
# 1456                 salad & dessert plates        Anna Weatherley      35.0
# 603                  coffee mugs & tea cups        Anna Weatherley      32.0
# 604                  coffee mugs & tea cups        Anna Weatherley      32.0
#
#      recom_class
# 1457        both
# 641         both
# 1464        both
# 7471        type
# 1454       brand
# 1262       brand
# 605        brand
# 562         type
# 197         type
# 1266       brand
# 2590        type
# 773        brand
# 1457        type
# 1457       brand
# 257         type
# 2558        type
# 1269       brand
# 1456       brand
# 603        brand
# 604        brand

# %%
result[result['CUSTOMER_DIM_KEY']==74134]
# Out:
#       CUSTOMER_DIM_KEY PRODUCT_DIM_KEY  \
# 3                74134           98182
# 2                74134           98181
# 5                74134           98184
# 4                74134           98183
# 11541            74134          493138
# 8670             74134          416774
# 13195            74134          510130
# 8232             74134          404120
# 3682             74134          200928
# 7112             74134          368634
# 8219             74134          404106
# 195              74134          108368
# 15779            74134          555406
# 196              74134          108369
# 3381             74134          190102
# 8560             74134          412658
# 4491             74134          304356
# 239              74134          109204
# 10946            74134          484584
# 197              74134          108370
#
#                                             PRODUCT_NAME    top_brand  \
# 3                                Bubble Medium Dish 5 oz  J.L. Coquet
# 2                                 Bubble Large Dish 7 oz  J.L. Coquet
# 5                                  Bubble Mini Dish 2 oz  J.L. Coquet
# 4                               Bubble Small Dish 3.5 oz  J.L. Coquet
# 11541                Labyrinthe 29-11 CM Engraved Plates  J.L. Coquet
# 8670                             Isabella Acrylic Goblet  J.L. Coquet
# 13195                         Bicos Frosted Black Goblet  J.L. Coquet
# 8232                                      Gravitas Omega  J.L. Coquet
# 3682                Christofle Cream Cleaner with Sponge  J.L. Coquet
# 7112   Assorted Giftware Butterfly Butter and Jam Spr...  J.L. Coquet
# 8219                                     Digestive Glass  J.L. Coquet
# 195               Hemisphere White Dinner Plate  10.6 in  J.L. Coquet
# 15779   Cordoba Acrylic Goblet, Recycled Green, 18.4 oz.  J.L. Coquet
# 196         Hemisphere White Dessert Plate 8.25 in Round  J.L. Coquet
# 3381             Rechargeable LED Light, Stainless Steel  J.L. Coquet
# 8560          SPECIAL SERVICE ITEM - Do not send to Lynx  J.L. Coquet
# 4491            Twiga Acrylic Wine Clear (Special Order)  J.L. Coquet
# 239               Hemisphere Platinum Presentation Plate  J.L. Coquet
# 10946                          Italia Acrylic Wine Clear  J.L. Coquet
# 197    Hemisphere White Bread & Butter Plate 6.25 in ...  J.L. Coquet
#
#       top_type  brand_conf  type_conf                           PRODUCT_TYPE  \
# 3      Unknown       0.875       0.25                                Unknown
# 2      Unknown       0.875       0.25                                Unknown
# 5      Unknown       0.875       0.25                                Unknown
# 4      Unknown       0.875       0.25                                Unknown
# 11541  Unknown       0.875       0.25                                Unknown
# 8670   Unknown       0.875       0.25                                Unknown
# 13195  Unknown       0.875       0.25                                Unknown
# 8232   Unknown       0.875       0.25                                Unknown
# 3682   Unknown       0.875       0.25                                Unknown
# 7112   Unknown       0.875       0.25                                Unknown
# 8219   Unknown       0.875       0.25                                Unknown
# 195    Unknown       0.875       0.25                          dinner plates
# 15779  Unknown       0.875       0.25                                Unknown
# 196    Unknown       0.875       0.25  dessert plates,salad & dessert plates
# 3381   Unknown       0.875       0.25                                Unknown
# 8560   Unknown       0.875       0.25                                Unknown
# 4491   Unknown       0.875       0.25                                Unknown
# 239    Unknown       0.875       0.25                      buffet & chargers
# 10946  Unknown       0.875       0.25                                Unknown
# 197    Unknown       0.875       0.25                  bread & butter plates
#
#                    BRAND  QUANTITY recom_class
# 3            J.L. Coquet      39.0        both
# 2            J.L. Coquet      16.0        both
# 5            J.L. Coquet       4.0        both
# 4            J.L. Coquet       4.0        both
# 11541        J.L. Coquet       1.0        both
# 8670             Juliska     144.0        type
# 13195       Vista Alegre     137.0        type
# 8232               Zalto     112.0        type
# 3682          Christofle      97.0        type
# 7112              Couzon      94.0        type
# 8219               Zalto      88.0        type
# 195          J.L. Coquet      86.0       brand
# 15779            TarHong      60.0        type
# 196          J.L. Coquet      57.0       brand
# 3381        Simon Pearce      57.0        type
# 8560      Gracious Style      56.0        type
# 4491   Mario Luca Giusti      54.0        type
# 239          J.L. Coquet      54.0       brand
# 10946  Mario Luca Giusti      54.0        type
# 197          J.L. Coquet      48.0       brand

# %%
result[result['CUSTOMER_DIM_KEY']==83076]
# Out:
#       CUSTOMER_DIM_KEY PRODUCT_DIM_KEY  \
# 3                83076           98182
# 2                83076           98181
# 5                83076           98184
# 4                83076           98183
# 11541            83076          493138
# 8670             83076          416774
# 13195            83076          510130
# 8232             83076          404120
# 3682             83076          200928
# 7112             83076          368634
# 8219             83076          404106
# 195              83076          108368
# 15779            83076          555406
# 196              83076          108369
# 3381             83076          190102
# 8560             83076          412658
# 4491             83076          304356
# 239              83076          109204
# 10946            83076          484584
# 197              83076          108370
#
#                                             PRODUCT_NAME    top_brand  \
# 3                                Bubble Medium Dish 5 oz  J.L. Coquet
# 2                                 Bubble Large Dish 7 oz  J.L. Coquet
# 5                                  Bubble Mini Dish 2 oz  J.L. Coquet
# 4                               Bubble Small Dish 3.5 oz  J.L. Coquet
# 11541                Labyrinthe 29-11 CM Engraved Plates  J.L. Coquet
# 8670                             Isabella Acrylic Goblet  J.L. Coquet
# 13195                         Bicos Frosted Black Goblet  J.L. Coquet
# 8232                                      Gravitas Omega  J.L. Coquet
# 3682                Christofle Cream Cleaner with Sponge  J.L. Coquet
# 7112   Assorted Giftware Butterfly Butter and Jam Spr...  J.L. Coquet
# 8219                                     Digestive Glass  J.L. Coquet
# 195               Hemisphere White Dinner Plate  10.6 in  J.L. Coquet
# 15779   Cordoba Acrylic Goblet, Recycled Green, 18.4 oz.  J.L. Coquet
# 196         Hemisphere White Dessert Plate 8.25 in Round  J.L. Coquet
# 3381             Rechargeable LED Light, Stainless Steel  J.L. Coquet
# 8560          SPECIAL SERVICE ITEM - Do not send to Lynx  J.L. Coquet
# 4491            Twiga Acrylic Wine Clear (Special Order)  J.L. Coquet
# 239               Hemisphere Platinum Presentation Plate  J.L. Coquet
# 10946                          Italia Acrylic Wine Clear  J.L. Coquet
# 197    Hemisphere White Bread & Butter Plate 6.25 in ...  J.L. Coquet
#
#       top_type  brand_conf  type_conf                           PRODUCT_TYPE  \
# 3      Unknown         0.5        0.5                                Unknown
# 2      Unknown         0.5        0.5                                Unknown
# 5      Unknown         0.5        0.5                                Unknown
# 4      Unknown         0.5        0.5                                Unknown
# 11541  Unknown         0.5        0.5                                Unknown
# 8670   Unknown         0.5        0.5                                Unknown
# 13195  Unknown         0.5        0.5                                Unknown
# 8232   Unknown         0.5        0.5                                Unknown
# 3682   Unknown         0.5        0.5                                Unknown
# 7112   Unknown         0.5        0.5                                Unknown
# 8219   Unknown         0.5        0.5                                Unknown
# 195    Unknown         0.5        0.5                          dinner plates
# 15779  Unknown         0.5        0.5                                Unknown
# 196    Unknown         0.5        0.5  dessert plates,salad & dessert plates
# 3381   Unknown         0.5        0.5                                Unknown
# 8560   Unknown         0.5        0.5                                Unknown
# 4491   Unknown         0.5        0.5                                Unknown
# 239    Unknown         0.5        0.5                      buffet & chargers
# 10946  Unknown         0.5        0.5                                Unknown
# 197    Unknown         0.5        0.5                  bread & butter plates
#
#                    BRAND  QUANTITY recom_class
# 3            J.L. Coquet      39.0        both
# 2            J.L. Coquet      16.0        both
# 5            J.L. Coquet       4.0        both
# 4            J.L. Coquet       4.0        both
# 11541        J.L. Coquet       1.0        both
# 8670             Juliska     144.0        type
# 13195       Vista Alegre     137.0        type
# 8232               Zalto     112.0        type
# 3682          Christofle      97.0        type
# 7112              Couzon      94.0        type
# 8219               Zalto      88.0        type
# 195          J.L. Coquet      86.0       brand
# 15779            TarHong      60.0        type
# 196          J.L. Coquet      57.0       brand
# 3381        Simon Pearce      57.0        type
# 8560      Gracious Style      56.0        type
# 4491   Mario Luca Giusti      54.0        type
# 239          J.L. Coquet      54.0       brand
# 10946  Mario Luca Giusti      54.0        type
# 197          J.L. Coquet      48.0       brand

# %%
result[result['CUSTOMER_DIM_KEY']==47059]
# Out:
#       CUSTOMER_DIM_KEY PRODUCT_DIM_KEY                     PRODUCT_NAME  \
# 8217             47059          404104                  Champagne Glass
# 8215             47059          404102                  Universal Glass
# 8214             47059          404101                   Bordeaux Glass
# 8213             47059          404100                   Burgundy Glass
# 8217             47059          404104                  Champagne Glass
# 8217             47059          404104                  Champagne Glass
# 8233             47059          404121                    Coupe/Tumbler
# 8216             47059          404103                 White Wine Glass
# 8221             47059          404108                      Water Glass
# 4360             47059          304151   Dolce Vita Acrylic Flute Clear
# 8218             47059          404105                 Sweet Wine Glass
# 4388             47059          304186   Dolce Vita Acrylic Flute White
# 14532            47059          534220           Isabella Acrylic Flute
# 8232             47059          404120                   Gravitas Omega
# 8226             47059          404113                Decanter Mystique
# 8225             47059          404112                   Decanter Axium
# 8219             47059          404106                  Digestive Glass
# 8223             47059          404110                     Carafe No 75
# 4374             47059          304170  Dolce Vita Acrylic Flute Violet
# 8224             47059          404111                    Carafe No 150
#
#       top_brand   top_type  brand_conf  type_conf      PRODUCT_TYPE  \
# 8217      Zalto  champagne         0.4        0.2         champagne
# 8215      Zalto  champagne         0.4        0.2  all purpose wine
# 8214      Zalto  champagne         0.4        0.2          red wine
# 8213      Zalto  champagne         0.4        0.2          red wine
# 8217      Zalto  champagne         0.4        0.2         champagne
# 8217      Zalto  champagne         0.4        0.2         champagne
# 8233      Zalto  champagne         0.4        0.2  drinking glasses
# 8216      Zalto  champagne         0.4        0.2        white wine
# 8221      Zalto  champagne         0.4        0.2     water goblets
# 4360      Zalto  champagne         0.4        0.2         champagne
# 8218      Zalto  champagne         0.4        0.2  all purpose wine
# 4388      Zalto  champagne         0.4        0.2         champagne
# 14532     Zalto  champagne         0.4        0.2         champagne
# 8232      Zalto  champagne         0.4        0.2           Unknown
# 8226      Zalto  champagne         0.4        0.2         decanters
# 8225      Zalto  champagne         0.4        0.2         decanters
# 8219      Zalto  champagne         0.4        0.2           Unknown
# 8223      Zalto  champagne         0.4        0.2           carafes
# 4374      Zalto  champagne         0.4        0.2         champagne
# 8224      Zalto  champagne         0.4        0.2           carafes
#
#                    BRAND  QUANTITY recom_class
# 8217               Zalto     742.0        both
# 8215               Zalto    1783.0       brand
# 8214               Zalto    1109.0       brand
# 8213               Zalto     850.0       brand
# 8217               Zalto     742.0       brand
# 8217               Zalto     742.0        type
# 8233               Zalto     284.0       brand
# 8216               Zalto     271.0       brand
# 8221               Zalto     177.0       brand
# 4360   Mario Luca Giusti     169.0        type
# 8218               Zalto     156.0       brand
# 4388   Mario Luca Giusti     121.0        type
# 14532            Juliska     112.0        type
# 8232               Zalto     112.0       brand
# 8226               Zalto      98.0       brand
# 8225               Zalto      92.0       brand
# 8219               Zalto      88.0       brand
# 8223               Zalto      80.0       brand
# 4374   Mario Luca Giusti      52.0        type
# 8224               Zalto      51.0       brand
